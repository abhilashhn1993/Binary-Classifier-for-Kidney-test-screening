# %%
conda install -c conda-forge textblob
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Out:
#   File "<ipython-input-15-bec4ba3f7ac1>", line 1
#     python -m textblob.download_corpora
#                      ^
# SyntaxError: invalid syntax

# %%
from textblob import TextBlob, Word, Blobber

# %%
python -m textblob.download_corpora
# Out:
#   File "<ipython-input-5-bec4ba3f7ac1>", line 1
#     python -m textblob.download_corpora
#                      ^
# SyntaxError: invalid syntax

# %%
txt = TextBlob("I feel very angry about the pandemic spreading around the world")

# %%
txt.sentiment
# Out:
# Sentiment(polarity=-0.65, subjectivity=1.0)

# %% [markdown]
# # Get old tweets method

# %%
import GetOldTweets3 as got

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('I have been diagnosed with PTSD')\
                                           .setSince("2019-05-01")\
                                           .setUntil("2020-03-20")\
                                           .setMaxTweets(100)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
print(tweet.text)
# Out:
# (Cont) I have been diagnosed with PTSD &amp; yet she treated me like this? But she used her mental health as an excuse to try getting away with it; and tried to make us look like bullies for being reasonably upset with her. Then continued to spread lies about us.

# %%
got.manager.TweetManager.getTweets(tweetCriteria)[0].text
# Out:
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=I%20have%20been%20diagnosed%20with%20PTSD%20since%3A2019-05-01%20until%3A2020-03-20&src=typd
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
tws
# Out:
# ...
#  'How I use music and creativity to process trauma. I have been diagnosed with the childhood presentation of PTSD (mainly avoidance &amp; shutdowns) so let the music speak for me when I express creatively. Usually paintings in metaphor transforming the trauma. ',
#  'Finally after what felt like forever I have been diagnosed with CFS along side my PTSD.. @DissociaDID video was the last puzzle piece.. My next question... What do I do now?',
#  '-apologized recently) that I Let myself be that way and that I should stop dwelling and just let go...(this was before I was let known and diagnosed with PTSD) So...its why I act strangely at times...and why I...have been such odd posts...and umm...responses from Blade..Anxiety-',
# ...

# %%
for i in range(1,100):
    tws.append(got.manager.TweetManager.getTweets(tweetCriteria)[i].text)
tws
# Out:
# ...
#  'How I use music and creativity to process trauma. I have been diagnosed with the childhood presentation of PTSD (mainly avoidance &amp; shutdowns) so let the music speak for me when I express creatively. Usually paintings in metaphor transforming the trauma. ',
#  'Finally after what felt like forever I have been diagnosed with CFS along side my PTSD.. @DissociaDID video was the last puzzle piece.. My next question... What do I do now?',
#  '-apologized recently) that I Let myself be that way and that I should stop dwelling and just let go...(this was before I was let known and diagnosed with PTSD) So...its why I act strangely at times...and why I...have been such odd posts...and umm...responses from Blade..Anxiety-',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(tws, columns=["colummn"])
df.to_csv('list.csv', index=False)
